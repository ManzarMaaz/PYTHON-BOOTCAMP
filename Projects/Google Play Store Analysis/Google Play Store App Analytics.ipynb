# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
df_apps.tail()
# Out:
#                   App Category  Rating   Reviews  Size_MBs       Installs  \
# 10836  Subway Surfers     GAME    4.50  27723193     76.00  1,000,000,000
# 10837  Subway Surfers     GAME    4.50  27724094     76.00  1,000,000,000
# 10838  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10839  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10840  Subway Surfers     GAME    4.50  27711703     76.00  1,000,000,000
#
#        Type Price Content_Rating  Genres   Last_Updated Android_Ver
# 10836  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10837  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10838  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10839  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up
# 10840  Free     0   Everyone 10+  Arcade  July 12, 2018  4.1 and up

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.sample(5)
# Out:
#                              App         Category  Rating  Reviews  Size_MBs  \
# 4172  BJ's Bingo & Gaming Casino             GAME    4.50      501     65.00
# 6947                 myChevrolet        LIFESTYLE    3.50     6747      8.35
# 417          AJ Orange Icon Pack  PERSONALIZATION     NaN        0     30.00
# 785              Bu Hangi Film ?           FAMILY     NaN        3     25.00
# 1171                       My EU           FAMILY    3.80        4     13.00
#
#        Installs  Type  Price Content_Rating           Genres     Last_Updated  \
# 4172     10,000  Free      0           Teen           Casino    July 26, 2018
# 6947  1,000,000  Free      0       Everyone        Lifestyle    June 11, 2018
# 417          10  Paid  $0.99       Everyone  Personalization      May 2, 2018
# 785         100  Free      0       Everyone           Puzzle  August 31, 2017
# 1171        100  Free      0       Everyone        Education     May 15, 2017
#
#              Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop('Android_Ver', axis=1, inplace=True)
df_apps.drop('Last_Updated', axis=1, inplace=True)

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps_cleaned = df_apps.dropna()
df_apps_cleaned.shape
# Out:
# (9367, 10)

# %%
df_apps.tail()
# Out:
#                   App Category  Rating   Reviews  Size_MBs       Installs  \
# 10836  Subway Surfers     GAME    4.50  27723193     76.00  1,000,000,000
# 10837  Subway Surfers     GAME    4.50  27724094     76.00  1,000,000,000
# 10838  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10839  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10840  Subway Surfers     GAME    4.50  27711703     76.00  1,000,000,000
#
#        Type Price Content_Rating  Genres
# 10836  Free     0   Everyone 10+  Arcade
# 10837  Free     0   Everyone 10+  Arcade
# 10838  Free     0   Everyone 10+  Arcade
# 10839  Free     0   Everyone 10+  Arcade
# 10840  Free     0   Everyone 10+  Arcade

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_cleaned.shape
# Out:
# (9367, 10)

# %%
df_apps_cleaned.duplicated()
# Out:
# 21       False
# 28       False
# 47       False
# 82       False
# 99       False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839     True
# 10840    False
# Length: 9367, dtype: bool

# %%
# 1. Sort by Reviews in descending order so the highest reviews are at the top
df_apps_cleaned = df_apps_cleaned.sort_values('Reviews', ascending=False)

# 2. Now drop duplicates. Since the highest reviews are at the top,
# the default keep='first' will preserve them.
df_apps_cleaned = df_apps_cleaned.drop_duplicates(subset=['App', 'Type', 'Price'])

# Check the shape to verify
df_apps_cleaned.shape
# Out:
# (8199, 10)

# %%
df_apps_cleaned.shape
# Out:
# (8199, 10)

# %%
df_apps_cleaned.tail()
# Out:
#                         App            Category  Rating  Reviews  Size_MBs  \
# 462                  CB Fit  HEALTH_AND_FITNESS    5.00        1      7.80
# 1208         Thistletown CI        PRODUCTIVITY    1.00        1      6.60
# 1374                  My CW               TOOLS    3.00        1     55.00
# 485   Familyfirst Messenger             MEDICAL    4.00        1      3.30
# 1593                 DG-App               TOOLS    5.00        1      4.50
#
#      Installs  Type Price Content_Rating            Genres
# 462        10  Free     0       Everyone  Health & Fitness
# 1208      100  Free     0       Everyone      Productivity
# 1374      100  Free     0       Everyone             Tools
# 485        10  Free     0       Everyone           Medical
# 1593      500  Free     0       Everyone             Tools

# %%
df_apps_cleaned.sort_values(by='Installs', ascending=False)
# Out:
#                                 App            Category  Rating   Reviews  \
# 10719                           Pou                GAME    4.30  10486018
# 10732                My Talking Tom                GAME    4.50  14892469
# 10734                 Facebook Lite              SOCIAL    4.30   8606259
# 10740              Google Translate               TOOLS    4.40   5745093
# 10773                       Dropbox        PRODUCTIVITY    4.40   1861310
# ...                             ...                 ...     ...       ...
# 2620   Next Launcher 3D Theme Hit-G     PERSONALIZATION    4.20        59
# 2671       BN Pro ArialXL-b HD Text  LIBRARIES_AND_DEMO    4.00        24
# 21              KBA-EZ Health Guide             MEDICAL    5.00         4
# 28                         Ra Ga Ba                GAME    5.00         2
# 47                          Mu.F.O.                GAME    5.00         2
#
#        Size_MBs     Installs  Type  Price Content_Rating            Genres
# ...

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_cleaned.max()
# Out:
# App               🔥 Football Wallpapers 4K | Full HD Backgrounds 😍
# Category                                                   WEATHER
# Rating                                                        5.00
# Reviews                                                   78158306
# Size_MBs                                                    100.00
# Installs                                               500,000,000
# Type                                                          Paid
# Price                                                            0
# Content_Rating                                             Unrated
# Genres                                                        Word
# dtype: object

# %%
df_apps_cleaned.sort_values(by='Reviews', ascending=False).head(10)
# Out:
#                                                      App       Category  \
# 10805                                           Facebook         SOCIAL
# 10789                                 WhatsApp Messenger  COMMUNICATION
# 10808                                          Instagram         SOCIAL
# 10790           Messenger – Text and Video Chat for Free  COMMUNICATION
# 10652                                     Clash of Clans           GAME
# 10744            Clean Master- Space Cleaner & Antivirus          TOOLS
# 10838                                     Subway Surfers           GAME
# 10828                                            YouTube  VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 10588                                       Clash Royale           GAME
#
#        Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_cleaned.sort_values(by='Size_MBs', ascending=False).head(5)
# Out:
#                                   App            Category  Rating  Reviews  \
# 7926                        Post Bank             FINANCE    4.50    60449
# 10688          Hungry Shark Evolution                GAME    4.50  6074627
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 1795             Navi Radiography Pro             MEDICAL    4.70       11
#
#        Size_MBs     Installs  Type   Price Content_Rating  \
# 7926     100.00    1,000,000  Free       0       Everyone
# 10688    100.00  100,000,000  Free       0           Teen
# 3144     100.00        5,000  Free       0       Everyone
# 9942     100.00   10,000,000  Free       0       Everyone
# 1795     100.00          500  Paid  $15.99       Everyone
#
#                        Genres
# 7926                  Finance
# 10688                  Arcade
# 3144         Health & Fitness
# 9942   Lifestyle;Pretend Play
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_cleaned.sort_values(by='Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10789                                 WhatsApp Messenger       COMMUNICATION
# 10808                                          Instagram              SOCIAL
# 10790           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10652                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10838                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10588                                       Clash Royale                GAME
# 10767                                   Candy Crush Saga                GAME
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_cleaned.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# %%
fig = px.pie(df_apps_cleaned, names='Content_Rating', title='Content Rating Distribution')
fig.show()

# %%
fig = px.pie(names=ratings.index, values=ratings.values, title='Content Rating Distribution')
fig.show()

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
)
fig.update_traces(textposition='outside', textinfo='percent+label')
 
fig.show()

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
hole=0.5
)
fig.update_traces(textposition='outside', textinfo='percent+label')
 
fig.show()

# %%
fig = px.histogram(df_apps_cleaned, x='Content_Rating', title='Content Rating Distribution')
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_cleaned.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1415
# Name: Installs, dtype: object

# %%
df_apps_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8199 entries, 10805 to 1593
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
df_apps_cleaned.Installs = df_apps_cleaned.Installs.str.replace(',', '').astype(int)
df_apps_cleaned.Installs = pd.to_numeric(df_apps_cleaned.Installs, errors='coerce')

# %%
df_apps_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8199 entries, 10805 to 1593
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 704.6+ KB

# %%
df_apps_cleaned[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        986
# 50000        457
# 100000      1095
# 500000       503
# 1000000     1415
# 5000000      607
# 10000000     937
# 50000000     204
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_cleaned.Price = df_apps_cleaned.Price.str.replace('$', '').astype(float)
df_apps_cleaned.Price = pd.to_numeric(df_apps_cleaned.Price, errors='coerce')

# %%
df_apps_cleaned.Price.describe()
# Out:
# count   8,199.00
# mean        1.04
# std        16.85
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max       400.00
# Name: Price, dtype: float64

# %%
df_apps_cleaned.sort_values(by='Price', ascending=False).head(10)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 1331          most expensive app (H)     FAMILY    4.30        6      1.50
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
#
#       Installs  Type  Price Content_Rating         Genres
# 3946     10000  Paid 400.00       Everyone      Lifestyle
# ...

# %%
df_apps_cleaned.Price.describe()
# Out:
# count   8,199.00
# mean        1.04
# std        16.85
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max       400.00
# Name: Price, dtype: float64

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_cleaned = df_apps_cleaned[df_apps_cleaned.Price < 250]
df_apps_cleaned.sort_values(by='Price', ascending=False).head(10)
# Out:
#                                                     App   Category  Rating  \
# 2281                          Vargo Anesthesia Mega App    MEDICAL    4.60
# 1407                                       LTC AS Legal    MEDICAL    4.00
# 2629                                   I am Rich Person  LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture    MEDICAL    3.50
# 504                           AP Art History Flashcards     FAMILY    5.00
# 2207                                           EMT PASS    MEDICAL    3.40
# 2463                                 PTA Content Master    MEDICAL    4.20
# 4264                            Golfshot Plus: Golf GPS     SPORTS    4.10
# 4774   Human Anatomy Atlas 2018: Complete 3D Human Body    MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...    MEDICAL    4.20
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating     Genres
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_cleaned['Revenue Estimate'] = df_apps_cleaned.Installs.mul(df_apps_cleaned.Price)
top10_grossing_apps = df_apps_cleaned.sort_values(by='Revenue Estimate', ascending=False)[:10]
top10_grossing_apps
# Out:
#                                 App       Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft         FAMILY    4.50  2376564     19.00
# 8825                  Hitman Sniper           GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas           GAME    4.40   348962     26.00
# 7977        Sleep as Android Unlock      LIFESTYLE    4.50    23966      0.85
# 7479            Facetune - For Free    PHOTOGRAPHY    4.40    49553     48.00
# 6594            DraStic DS Emulator           GAME    4.60    87766     12.00
# 6082                   Weather Live        WEATHER    4.50    76593      4.75
# 6856                        Threema  COMMUNICATION    4.50    51110      3.50
# 7954                    Bloons TD 5         FAMILY    4.60   190086     94.00
# 7633        Five Nights at Freddy's           GAME    4.60   100805     50.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# ...

# %%
top10_grossing_apps[top10_grossing_apps.Category == 'GAME']
# Out:
#                                 App Category  Rating  Reviews  Size_MBs  \
# 8825                  Hitman Sniper     GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas     GAME    4.40   348962     26.00
# 6594            DraStic DS Emulator     GAME    4.60    87766     12.00
# 7633        Five Nights at Freddy's     GAME    4.60   100805     50.00
#
#       Installs  Type  Price Content_Rating  Genres  Revenue Estimate
# 8825  10000000  Paid   0.99     Mature 17+  Action      9,900,000.00
# 7151   1000000  Paid   6.99     Mature 17+  Action      6,990,000.00
# 6594   1000000  Paid   4.99       Everyone  Action      4,990,000.00
# 7633   1000000  Paid   2.99           Teen  Action      2,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_cleaned.groupby('Category')['Revenue Estimate'].sum().sort_values(ascending=False)
# Out:
# Category
# FAMILY                105,729,057.70
# GAME                   40,687,840.88
# PHOTOGRAPHY             8,546,049.80
# PERSONALIZATION         6,796,309.80
# LIFESTYLE               6,205,149.40
# MEDICAL                 5,872,355.00
# TOOLS                   5,462,910.30
# SPORTS                  4,706,154.00
# PRODUCTIVITY            4,304,451.90
# COMMUNICATION           4,247,100.00
# WEATHER                 4,179,885.00
# HEALTH_AND_FITNESS      1,420,270.00
# MAPS_AND_NAVIGATION     1,240,789.00
# TRAVEL_AND_LOCAL        1,149,250.00
# BUSINESS                1,047,648.40
# ENTERTAINMENT             798,000.00
# FINANCE                   527,274.00
# EDUCATION                 408,980.00
# VIDEO_PLAYERS             335,290.00
# FOOD_AND_DRINK            284,400.00
# PARENTING                 249,959.00
# AUTO_AND_VEHICLES          99,500.00
# BOOKS_AND_REFERENCE        88,901.50
# DATING                     47,689.00
# ART_AND_DESIGN             31,840.00
# ...

# %%
top10_catergories = df_apps_cleaned['Category'].value_counts()[:10]
top10_catergories
# Out:
# Category
# FAMILY             1645
# GAME                899
# TOOLS               720
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             291
# PHOTOGRAPHY         263
# BUSINESS            263
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
px.bar(x=top10_catergories.index,
       y=top10_catergories.values,
       title='Top 10 App Categories',
       labels={'x':'Category', 'y':'Number of Apps'})

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_apps_cleaned.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 38252676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97072000
# ART_AND_DESIGN         113233100
# DATING                 140912410
# EDUCATION              189852000
# FOOD_AND_DRINK         211677750
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               697018120
# ENTERTAINMENT          989660000
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1144006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3931797200
# PHOTOGRAPHY           4658143130
# ...

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Total Installs per Category',
               labels={'x':'Total Installs', 'y':'Category'})
 
h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
category_number = df_apps_cleaned.groupby('Category').agg({'App': pd.Series.count})
category_number.sort_values('App', ascending=False, inplace=True)
category_number
# Out:
#                       App
# Category
# FAMILY               1645
# GAME                  899
# TOOLS                 720
# PRODUCTIVITY          301
# PERSONALIZATION       298
# LIFESTYLE             297
# FINANCE               296
# MEDICAL               291
# BUSINESS              263
# PHOTOGRAPHY           263
# SPORTS                260
# COMMUNICATION         256
# HEALTH_AND_FITNESS    244
# NEWS_AND_MAGAZINES    204
# SOCIAL                203
# TRAVEL_AND_LOCAL      187
# SHOPPING              180
# BOOKS_AND_REFERENCE   169
# VIDEO_PLAYERS         149
# DATING                134
# MAPS_AND_NAVIGATION   118
# EDUCATION             106
# FOOD_AND_DRINK         94
# ENTERTAINMENT          87
# AUTO_AND_VEHICLES      73
# WEATHER                72
# LIBRARIES_AND_DEMO     64
# HOUSE_AND_HOME         61
# ART_AND_DESIGN         59
# COMICS                 54
# PARENTING              50
# EVENTS                 45
# BEAUTY                 42

# %%
category_number_installs = category_number.merge(category_installs, left_index=True, right_index=True)
category_number_installs.rename(columns={'App':'Number of Apps', 'Installs':'Total Installs'}, inplace=True)
category_number_installs
# Out:
#                      Number of Apps  Total Installs
# Category
# FAMILY                         1645      6220954490
# GAME                            899     13457762717
# TOOLS                           720      8100724500
# PRODUCTIVITY                    301      5793070180
# PERSONALIZATION                 298      1532352930
# LIFESTYLE                       297       503611120
# FINANCE                         296       455249400
# MEDICAL                         291        38252676
# BUSINESS                        263       697018120
# PHOTOGRAPHY                     263      4658143130
# SPORTS                          260      1096431465
# COMMUNICATION                   256     11038241530
# HEALTH_AND_FITNESS              244      1144006220
# NEWS_AND_MAGAZINES              204      2369110650
# SOCIAL                          203      5487841475
# TRAVEL_AND_LOCAL                187      2894859300
# SHOPPING                        180      1400331540
# ...

# %%
print(f"The Dimesion of the dataframe is: {category_number_installs.shape}")
# Out:
# The Dimesion of the dataframe is: (33, 2)

# %%
scatter = px.scatter(category_number_installs, # data
                    x='Number of Apps', # column name
                    y='Total Installs',
                    title='Category Concentration',
                    size='Number of Apps',
                    hover_name=category_number_installs.index,
                    color='Total Installs')
 
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))
 
scatter.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
print(df_apps_cleaned.Genres,"\n")
print(df_apps_cleaned.Genres.nunique())
# Out:
# 10805              Social
# 10789       Communication
# 10808              Social
# 10790       Communication
# 10652            Strategy
#                ...
# 462      Health & Fitness
# 1208         Productivity
# 1374                Tools
# 485               Medical
# 1593                Tools
# Name: Genres, Length: 8184, dtype: object
#
# 114

# %%
stack = df_apps_cleaned.Genres.str.split(';', expand=True).stack()
print(stack)
# Out:
# 10805  0              Social
# 10789  0       Communication
# 10808  0              Social
# 10790  0       Communication
# 10652  0            Strategy
#                   ...
# 462    0    Health & Fitness
# 1208   0        Productivity
# 1374   0               Tools
# 485    0             Medical
# 1593   0               Tools
# Length: 8562, dtype: object

# %%
print(f'Shape of the stacked series: {stack.shape}')
# Out:
# Shape of the stacked series: (8562,)

# %%
num_of_genres = stack.value_counts()

# %%
print(f'Total Number of Genres: {len(num_of_genres)}')
# Out:
# Total Number of Genres: 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x = num_of_genres.index[:15], # index = category name
             y = num_of_genres.values[:15], # count
             title='Top Genres',
             hover_name=num_of_genres.index[:15],
             color=num_of_genres.values[:15],
             color_continuous_scale='Agsunset')
 
bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)
 
bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_paid = df_apps_cleaned[df_apps_cleaned.Type == 'Paid']
df_apps_free = df_apps_cleaned[df_apps_cleaned.Type == 'Free']

print(f'Paid Apps Shape: {df_apps_paid.shape}')
print(f'Free Apps Shape: {df_apps_free.shape}')
# Out:
# Paid Apps Shape: (589, 11)
# Free Apps Shape: (7595, 11)

# %%
df_apps_cleaned.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
df_paid_vs_free = df_apps_cleaned.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})
df_paid_vs_free
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   56
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  145
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(df_paid_vs_free,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_xaxes(tickangle=-45)
g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
 
g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_cleaned,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
box = px.box(df_apps_cleaned[df_apps_cleaned.Type == 'Paid'],
             x='Category',
             y='Revenue Estimate',
             notched=True,
             points='all',
             title='Revenue Distribution by Category')
box.update_layout(yaxis=dict(type='log'))
box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
